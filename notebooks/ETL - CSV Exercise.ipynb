# %% [markdown]
# # Extracting data from a csv file (local and online)
#
# The following csv file will be used:
#
# - COVID-19 Daily Reports
#
# We will be importing the data using the pandas read_csv method to put the data in a pandas DataFrame.

# %%
#import our dependencies for this project
import pandas as pd
import os

# %%
print(os.getcwd())
# Out:
# /Users/adrian/Documents/Full Stack Bytes/ETL/etl_python

# %%
#Read the CSV file from our data folder into a pandas Dataframe
covid_daily_us = pd.read_csv('05-28-2020.csv')

# %%
#Return first five rows of data
covid_daily_us
# Out:
#               Province_State Country_Region          Last_Update      Lat  \
# 0                    Alabama             US  2020-05-29 02:32:58  32.3182
# 1                     Alaska             US  2020-05-29 02:32:58  61.3707
# 2             American Samoa             US  2020-05-29 02:32:58 -14.2710
# 3                    Arizona             US  2020-05-29 02:32:58  33.7298
# 4                   Arkansas             US  2020-05-29 02:32:58  34.9697
# 5                 California             US  2020-05-29 02:32:58  36.1162
# 6                   Colorado             US  2020-05-29 02:32:58  39.0598
# 7                Connecticut             US  2020-05-29 02:32:58  41.5978
# 8                   Delaware             US  2020-05-29 02:32:58  39.3185
# 9           Diamond Princess             US  2020-05-29 02:32:58      NaN
# 10      District of Columbia             US  2020-05-29 02:32:58  38.8974
# 11                   Florida             US  2020-05-29 02:32:58  27.7663
# ...
